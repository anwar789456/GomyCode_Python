# %% [markdown]
# # Rectify the code in each cell and **explain the error in comments**

# %% [markdown]
# ### index error

# %%
mylist=[14, "hello", 967]
mylist[0]
# trying to access an item at an invalid index.
# the length of my list is 3 so there is no value in mylist[6]
# i will change the value 6 to 0, that way it will print the first value which is '14'
# Out:
# 14

# %%
import pandas
import numpy

# Pandas is invalid, it should be written as pandas
# NumPy is invalid, it should be written as numpy

# %% [markdown]
# # syntax error

# %%
print("python errors")
# Print should be written like this : "print"
# and there were parentheses missing between the "python errors" message
# Out:
# python errors

# %% [markdown]
# # key error

# %%
mydictionnary={"True":"hello","False":"bye", '3':"python"}
mydictionnary['True']
# the key is not found because it was initialized without quotes
# Out:
# 'hello'

# %% [markdown]
# # indentation error

# %%
i=14
while i<78:
  print(i)
i+=1
# identation was missing in the 3rd line
# Out:
# Streaming output truncated to the last 5000 lines.
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# ...

# %% [markdown]
# # StopIteration

# %%
it=iter([1,2,3])
next(it)
next(it)
next(it)
#next(it) --> this line should be deleted

# the next() function went beyond the iterator items.
# Out:
# 3

# %% [markdown]
# # TypeError

# %%
15+15
# we can't do operations on variables with different types so i changed the first variable from string to integer
# Out:
# 30

# %% [markdown]
# # ValueError

# %%
"""int('python')"""
# we can't convert a string to an integer unless the string contains a number, and this one doesn't
# let me change the code to make it work
int("123")
# Out:
# 123

# %% [markdown]
# # NameError

# %%
"""python"""

# python was not defined so it can't be printed
# here is a little change in the code to make it work:
python = "python rocks!"
python
# Out:
# 'python rocks!'

# %% [markdown]
# # ZeroDivisionError

# %%
x=19/0
# you can't devide by zero, python will show an error
# Out:
# ZeroDivisionErrorTraceback (most recent call last)
# <ipython-input-15-523d4565e4d9> in <module>()
# ----> 1 x=19/0
#
# ZeroDivisionError: integer division or modulo by zero
